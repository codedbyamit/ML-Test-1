# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("placement.csv")
df = df.iloc[:,1:]
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X = df.iloc[:,0:2]
Y = df.iloc[:,-1]
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X_train,Y_train)
Y_pred = clf.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(Y_test,Y_pred)
# !pip install mlxtend
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X_train, Y_train.values, clf=clf, legend=2)
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\codes\helloworld\.venv\lib\site-packages (from mlxtend) (1.15.3)
# Requirement already satisfied: numpy>=1.16.2 in c:\codes\helloworld\.venv\lib\site-packages (from mlxtend) (2.3.0)
# Requirement already satisfied: pandas>=0.24.2 in c:\codes\helloworld\.venv\lib\site-packages (from mlxtend) (2.3.0)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\codes\helloworld\.venv\lib\site-packages (from mlxtend) (1.7.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\codes\helloworld\.venv\lib\site-packages (from mlxtend) (3.10.3)
# Requirement already satisfied: joblib>=0.13.2 in c:\codes\helloworld\.venv\lib\site-packages (from mlxtend) (1.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\codes\helloworld\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\codes\helloworld\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\codes\helloworld\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\codes\helloworld\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\codes\helloworld\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in c:\codes\helloworld\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\codes\helloworld\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\codes\helloworld\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\codes\helloworld\.venv\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\codes\helloworld\.venv\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\codes\helloworld\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\codes\helloworld\.venv\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 24.4 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4
# <Axes: >

# %%
import pickle
pickle.dump(clf,open('model.pkl','wb'))
